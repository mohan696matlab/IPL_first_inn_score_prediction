# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# To show all the columns
pd.pandas.set_option('display.max_column',None)

# %% [markdown]
# # Importing the dataset

# %%
df= pd.read_csv('IPL_dataset.csv')

# %%
df.columns
# Out:
# Index(['mid', 'date', 'venue', 'bat_team', 'bowl_team', 'batsman', 'bowler',
#        'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
#        'non-striker', 'total'],
#       dtype='object')

# %% [markdown]
# # Columns to remove

# %%
remove_col = ['mid','venue','date','batsman', 'bowler','striker',
       'non-striker']

df.drop(columns=remove_col,inplace=True)

# %%
df
# Out:
#                     bat_team                    bowl_team  runs  wickets  \
# 0      Kolkata Knight Riders  Royal Challengers Bangalore     1        0
# 1      Kolkata Knight Riders  Royal Challengers Bangalore     1        0
# 2      Kolkata Knight Riders  Royal Challengers Bangalore     2        0
# 3      Kolkata Knight Riders  Royal Challengers Bangalore     2        0
# 4      Kolkata Knight Riders  Royal Challengers Bangalore     2        0
# ...                      ...                          ...   ...      ...
# 76009         Mumbai Indians       Rising Pune Supergiant   121        7
# 76010         Mumbai Indians       Rising Pune Supergiant   127        7
# 76011         Mumbai Indians       Rising Pune Supergiant   128        7
# 76012         Mumbai Indians       Rising Pune Supergiant   129        7
# 76013         Mumbai Indians       Rising Pune Supergiant   129        8
#
#        overs  runs_last_5  wickets_last_5  total
# ...

# %%
df['bat_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Deccan Chargers', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant'], dtype=object)

# %% [markdown]
# # Keeping the teams who are currently playing

# %%
consistent_teams = ['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals','Mumbai Indians',  'Kings XI Punjab','Royal Challengers Bangalore', 'Delhi Daredevils','Sunrisers Hyderabad']

# %%
df=df[(df['bat_team'].isin(consistent_teams)) & (df['bowl_team'].isin(consistent_teams))]

# %% [markdown]
# # Removing thr first 5 overs data

# %%
df = df[df['overs']>=5.0]
df
# Out:
#                     bat_team                    bowl_team  runs  wickets  \
# 32     Kolkata Knight Riders  Royal Challengers Bangalore    61        0
# 33     Kolkata Knight Riders  Royal Challengers Bangalore    61        1
# 34     Kolkata Knight Riders  Royal Challengers Bangalore    61        1
# 35     Kolkata Knight Riders  Royal Challengers Bangalore    61        1
# 36     Kolkata Knight Riders  Royal Challengers Bangalore    61        1
# ...                      ...                          ...   ...      ...
# 75884  Kolkata Knight Riders               Mumbai Indians   106        9
# 75885  Kolkata Knight Riders               Mumbai Indians   107        9
# 75886  Kolkata Knight Riders               Mumbai Indians   107        9
# 75887  Kolkata Knight Riders               Mumbai Indians   107        9
# 75888  Kolkata Knight Riders               Mumbai Indians   107       10
#
#        overs  runs_last_5  wickets_last_5  total
# ...

# %% [markdown]
# # OneHotEncoding

# %%
encoded_df= pd.get_dummies(df,drop_first=True)

# %%
encoded_df.head(10)
# Out:
#     runs  wickets  overs  runs_last_5  wickets_last_5  total  \
# 32    61        0    5.1           59               0    222
# 33    61        1    5.2           59               1    222
# 34    61        1    5.3           59               1    222
# 35    61        1    5.4           59               1    222
# 36    61        1    5.5           58               1    222
# 37    61        1    5.6           58               1    222
# 38    62        1    6.1           55               1    222
# 39    63        1    6.2           52               1    222
# 40    64        1    6.3           47               1    222
# 41    66        1    6.4           45               1    222
#
#     bat_team_Delhi Daredevils  bat_team_Kings XI Punjab  \
# 32                          0                         0
# 33                          0                         0
# 34                          0                         0
# 35                          0                         0
# ...

# %% [markdown]
# # Splitting into X and y

# %%
encoded_df.shape
# Out:
# (40108, 20)

# %%
X = encoded_df.drop(columns=['total'])
y= encoded_df['total']

# %%
X
# Out:
#        runs  wickets  overs  runs_last_5  wickets_last_5  \
# 32       61        0    5.1           59               0
# 33       61        1    5.2           59               1
# 34       61        1    5.3           59               1
# 35       61        1    5.4           59               1
# 36       61        1    5.5           58               1
# ...     ...      ...    ...          ...             ...
# 75884   106        9   18.1           29               4
# 75885   107        9   18.2           29               4
# 75886   107        9   18.3           28               4
# 75887   107        9   18.4           24               4
# 75888   107       10   18.5           23               5
#
#        bat_team_Delhi Daredevils  bat_team_Kings XI Punjab  \
# 32                             0                         0
# 33                             0                         0
# 34                             0                         0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,shuffle =False)

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV


lasso=Lasso()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)

lasso_regressor.fit(X_train,y_train)
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# C:\Users\mohan\miniconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3676383.5947006727, tolerance: 2156.9975636395516
#   positive)
# C:\Users\mohan\miniconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3824089.5402291236, tolerance: 2125.01027362967
#   positive)
# C:\Users\mohan\miniconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3714865.316074146, tolerance: 2214.038380458918
#   positive)
# ...

# %%
prediction=lasso_regressor.predict(X_test)

plt.scatter(y_test,prediction)

axes = plt.gca()
axes.set_xlim([0,280])
axes.set_ylim([0,280])

from sklearn import metrics
print('MSE:', metrics.mean_squared_error(y_test, prediction))
# Out:
# MSE: 309.96536733941235

# %%
sns.distplot(y_test-prediction)

# %%
import pickle
# open a file, where you ant to store the data
file = open('IPL_model.pkl', 'wb')

# dump information to that file
pickle.dump(lasso_regressor, file)

# %% [markdown]
# # Testing the data set

# %%
def predict(batting_team,bowling_team,overs,runs,wickets,runs_in_prev_5,wickets_in_prev_5):
    temp_array = list()
    
    
        
    
    if batting_team == 'Chennai Super Kings':
        temp_array = temp_array + [0,0,0,0,0,0,0]
    elif batting_team == 'Delhi Daredevils':
        temp_array = temp_array + [1,0,0,0,0,0,0]
    elif batting_team == 'Kings XI Punjab':
        temp_array = temp_array + [0,1,0,0,0,0,0]
    elif batting_team == 'Kolkata Knight Riders':
        temp_array = temp_array + [0,0,1,0,0,0,0]
    elif batting_team == 'Mumbai Indians':
        temp_array = temp_array + [0,0,0,1,0,0,0]
    elif batting_team == 'Rajasthan Royals':
        temp_array = temp_array + [0,0,0,0,1,0,0]
    elif batting_team == 'Royal Challengers Bangalore':
        temp_array = temp_array + [0,0,0,0,0,1,0]
    elif batting_team == 'Sunrisers Hyderabad':
        temp_array = temp_array + [0,0,0,0,0,0,1]



    if bowling_team == 'Chennai Super Kings':
        temp_array = temp_array + [0,0,0,0,0,0,0]
    elif bowling_team == 'Delhi Daredevils':
        temp_array = temp_array + [1,0,0,0,0,0,0]
    elif bowling_team == 'Kings XI Punjab':
        temp_array = temp_array + [0,1,0,0,0,0,0]
    elif bowling_team == 'Kolkata Knight Riders':
        temp_array = temp_array + [0,0,1,0,0,0,0]
    elif bowling_team == 'Mumbai Indians':
        temp_array = temp_array + [0,0,0,1,0,0,0]
    elif bowling_team == 'Rajasthan Royals':
        temp_array = temp_array + [0,0,0,0,1,0,0]
    elif bowling_team == 'Royal Challengers Bangalore':
        temp_array = temp_array + [0,0,0,0,0,1,0]
    elif bowling_team == 'Sunrisers Hyderabad':
        temp_array = temp_array + [0,0,0,0,0,0,1]


    temp_array =  [overs,  wickets, runs, runs_in_prev_5, wickets_in_prev_5]+temp_array 

    data = np.reshape(temp_array,(1,-1))
    my_prediction = int(lasso_regressor.predict(data)[0])
              
    return my_prediction

# %%
batting_team = input("batting_team : ")
bowling_team = input("bowling_team : ")
overs = input("overs : ")
runs = input("runs : ")
wickets = input("wickets : ")
runs_in_prev_5 = input("runs_in_prev_5 : ")
wickets_in_prev_5 = input("wickets_in_prev_5 : ")

my_prediction = predict(batting_team,bowling_team,float(overs),int(runs),int(wickets),int(runs_in_prev_5),int(wickets_in_prev_5))

print('Predicted score is between {} - {}'.float(my_prediction-5,my_prediction+5))
# Out:
# batting_team : 'Chennai Super Kings'
# bowling_team : 'Delhi Daredevils'
# overs : 13
# runs : 100
# wickets : 4
# runs_in_prev_5 : 34
# wickets_in_prev_5 : 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-e976e652f0bf> in <module>
#       7 wickets_in_prev_5 = input("wickets_in_prev_5 : ")
#       8
# ----> 9 my_prediction = predict(batting_team,bowling_team,float(overs),int(runs),int(wickets),int(runs_in_prev_5),int(wickets_in_prev_5))
#      10
#      11 print('Predicted score is between {} - {}'.float(my_prediction-5,my_prediction+5))
#
# <ipython-input-48-c7daa2db1d45> in predict(batting_team, bowling_team, overs, runs, wickets, runs_in_prev_5, wickets_in_prev_5)
#      45
#      46     data = np.array([temp_array])
# ---> 47     my_prediction = int(lasso_regressor.predict(data)[0])
#      48
#      49     return my_prediction
#
# ...
